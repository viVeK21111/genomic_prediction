# %%
import pandas as pd
df=pd.read_csv("G:\My Drive\ps\data\ddata.csv")

# %%
df=df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#         0    1    2     3    4    5    6    7    8          subpopulation  \
# 0    0.75  0.5  0.5  2.50  2.5  2.5  0.5  2.5  2.5                    Aus
# 1    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5    Indica Intermediate
# 2    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5             Indica III
# 3    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5    Indica Intermediate
# 4    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5             Indica III
# ..    ...  ...  ...   ...  ...  ...  ...  ...  ...                    ...
# 524  0.75  0.5  2.5  0.75  1.5  1.5  0.5  0.5  0.5     Temperate Japonica
# 525  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5  Japonica Intermediate
# 526  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5     Temperate Japonica
# 527  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5     Temperate Japonica
# 528  1.50  0.5  0.5  0.75  1.5  2.5  0.5  2.5  2.5           Intermediate
#
#      height
# 0    145.80
# 1    185.60
# 2    203.60
# 3    190.20
# 4    193.80
# ..      ...
# 524  192.07
# 525  196.80
# 526  206.73
# 527  172.46
# 528  149.80
#
# [529 rows x 11 columns]

# %%
x=df.iloc[:,:-2]
y=df.iloc[:,-2]
z=df.iloc[:,-1]

# %%
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(x, y)

# %%
x,y
# Out:
# (        0    1    2     3    4    5    6    7    8
#  0    0.75  0.5  0.5  2.50  2.5  2.5  0.5  2.5  2.5
#  1    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5
#  2    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5
#  3    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5
#  4    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5
#  ..    ...  ...  ...   ...  ...  ...  ...  ...  ...
#  524  0.75  0.5  2.5  0.75  1.5  1.5  0.5  0.5  0.5
#  525  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5
#  526  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5
#  527  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5
#  528  1.50  0.5  0.5  0.75  1.5  2.5  0.5  2.5  2.5
#
#  [529 rows x 9 columns],
#  0                        Aus
#  1        Indica Intermediate
#  2                 Indica III
#  3        Indica Intermediate
#  4                 Indica III
#                 ...
#  524       Temperate Japonica
#  525    Japonica Intermediate
#  526       Temperate Japonica
#  527       Temperate Japonica
#  528             Intermediate
#  Name: subpopulation, Length: 529, dtype: object)

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
x_pca=pca.fit_transform(X_resampled)
x_pca
# Out:
# array([[ 0.66455364,  0.64448848],
#        [-0.28841118,  1.91346173],
#        [-0.28841118,  1.91346173],
#        ...,
#        [ 2.54220305,  0.04916053],
#        [ 2.43347867,  0.66344359],
#        [ 2.56052491,  0.80008557]])

# %%
x
# Out:
#         0    1    2     3    4    5    6    7    8
# 0    0.75  0.5  0.5  2.50  2.5  2.5  0.5  2.5  2.5
# 1    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5
# 2    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5
# 3    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5
# 4    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5
# ..    ...  ...  ...   ...  ...  ...  ...  ...  ...
# 524  0.75  0.5  2.5  0.75  1.5  1.5  0.5  0.5  0.5
# 525  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5
# 526  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5
# 527  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5
# 528  1.50  0.5  0.5  0.75  1.5  2.5  0.5  2.5  2.5
#
# [529 rows x 9 columns]

# %%
xxxx=pca.fit_transform(x)
xxxx
# Out:
# array([[ 0.95587151,  0.18224424],
#        [ 0.16786615,  1.57867559],
#        [ 0.16786615,  1.57867559],
#        ...,
#        [ 1.38244203, -0.29763279],
#        [ 1.38244203, -0.29763279],
#        [ 0.75094705, -1.10712828]])

# %%
import numpy as np
import matplotlib.pyplot as plt
classes = np.unique(y_resampled)

# Set up colors for each class
colors = ['red', 'blue', 'green', 'orange','yellow','black','brown','indigo','grey','purple']  # Add more colors if needed
# Plot scatter plot
for i, class_label in enumerate(classes):
    # Filter data points belonging to the current class
    X_class = x_pca[y_resampled == class_label]

    # Scatter plot for the current class
    plt.scatter(X_class[:, 0], X_class[:, 1], color=colors[i], label=f'Class {class_label}')

# Set labels and title
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Scatter Plot of Multi-Class Classification')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Multi-Class Classification')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_resampled,y_resampled,random_state=42,test_size=0.33)

# %%
#model_r=RandomForestClassifier(n_estimators=7,max_depth=9,random_state=42,criterion="gini",max_features='sqrt',max_leaf_nodes=30)

# %%
x_train=pd.DataFrame(x_train)
x_train
# Out:
#              0    1         2         3         4    5    6    7    8
# 339   0.750000  0.5  2.500000  2.500000  2.500000  1.5  2.5  2.5  2.5
# 1063  0.750000  0.5  2.500000  0.750000  2.500000  1.5  0.5  2.5  2.5
# 527   0.750000  0.5  2.500000  2.500000  1.500000  1.5  0.5  0.5  0.5
# 1000  0.750000  0.5  2.500000  0.750000  2.500000  1.5  0.5  2.5  2.5
# 137   0.750000  0.5  0.500000  0.750000  2.500000  2.5  0.5  0.5  0.5
# ...        ...  ...       ...       ...       ...  ...  ...  ...  ...
# 1044  0.750000  0.5  2.500000  0.750000  1.500000  1.5  2.5  2.5  2.5
# 1095  0.750000  0.5  0.500000  1.148887  2.500000  2.5  0.5  0.5  0.5
# 1130  0.750000  0.5  1.043567  0.750000  2.500000  2.5  0.5  0.5  0.5
# 860   1.083599  0.5  2.500000  0.750000  1.944799  1.5  0.5  2.5  2.5
# 1126  0.750000  0.5  2.015889  0.750000  2.500000  2.5  0.5  0.5  0.5
#
# [783 rows x 9 columns]

# %%
x_test=pd.DataFrame(x_test)
x_test
# Out:
#         0    1         2         3    4    5         6    7         8
# 626  0.75  0.5  2.500000  2.500000  2.5  1.5  2.500000  2.5  2.500000
# 220  1.50  0.5  2.500000  0.750000  2.5  1.5  0.500000  2.5  2.500000
# 678  0.75  0.5  2.500000  2.500000  2.5  2.5  1.302269  2.5  2.500000
# 963  1.50  0.5  2.500000  0.750000  2.5  1.5  0.500000  2.5  2.500000
# 174  0.75  0.5  2.500000  0.750000  2.5  1.5  0.500000  2.5  2.500000
# ..    ...  ...       ...       ...  ...  ...       ...  ...       ...
# 567  0.75  0.5  0.500000  0.750000  2.5  2.5  0.500000  2.5  0.500000
# 462  0.75  0.5  2.500000  0.750000  2.5  1.5  2.500000  2.5  2.500000
# 261  0.75  0.5  2.500000  0.750000  2.5  2.5  2.500000  2.5  0.500000
# 448  0.75  0.5  2.500000  0.750000  2.5  1.5  2.500000  2.5  2.500000
# 944  0.75  0.5  1.038825  2.028528  2.5  1.5  0.500000  0.5  1.961175
#
# [387 rows x 9 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import train_test_split
model_r=RandomForestClassifier(n_estimators=7,max_depth=9,random_state=42,criterion="gini",max_features='sqrt',max_leaf_nodes=30) 
model_r.fit(x_train,y_train)
r_pred=model_r.predict(x_test)
print(accuracy_score(y_test,r_pred))

s_pred=model_r.predict(x)
s_pred=list(s_pred)
df_h=pd.DataFrame(df.iloc[:,:-2]) 
df_h['sub']=s_pred 
df_h['sub']=df_h['sub'].astype("category").cat.codes +1  
df_h['height']=z
df_h.columns=df_h.columns.astype(str)   


def Outlier_Treatment(df1,variable):
    global df_final
    percentile25=df1[variable].quantile(0.25)  #q1
    percentile75=df1[variable].quantile(0.75)  #q3
    iqr=percentile75-percentile25
    upper_limit=percentile75+1.5*iqr
    lower_limit=percentile25-1.5*iqr
    df_final = df1[ (df1[variable]>=lower_limit) & (df1[variable]<=upper_limit) ]
Outlier_Treatment(df_h,'height')
# Out:
# 0.7467700258397932

# %%
tr_ac=model_r.predict(x_train)
accuracy_score(y_train,tr_ac)
# Out:
# 0.7522349936143039

# %%
df_final
# Out:
#         0    1    2     3    4    5    6    7    8  sub  height
# 0    0.75  0.5  0.5  2.50  2.5  2.5  0.5  2.5  2.5    1  145.80
# 1    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5    4  185.60
# 2    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5    4  203.60
# 3    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5    4  190.20
# 4    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5    4  193.80
# ..    ...  ...  ...   ...  ...  ...  ...  ...  ...  ...     ...
# 524  0.75  0.5  2.5  0.75  1.5  1.5  0.5  0.5  0.5    8  192.07
# 525  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5    8  196.80
# 526  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5    8  206.73
# 527  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5    8  172.46
# 528  1.50  0.5  0.5  0.75  1.5  2.5  0.5  2.5  2.5    1  149.80
#
# [528 rows x 11 columns]

# %%
xh=df_final.iloc[:,:-1]
yh=df_final.iloc[:,-1]

# %%
xh,yh
# Out:
# (        0    1    2     3    4    5    6    7    8  sub
#  0    0.75  0.5  0.5  2.50  2.5  2.5  0.5  2.5  2.5    1
#  1    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5    4
#  2    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5    4
#  3    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5    4
#  4    0.75  0.5  0.5  2.50  2.5  2.5  2.5  2.5  2.5    4
#  ..    ...  ...  ...   ...  ...  ...  ...  ...  ...  ...
#  524  0.75  0.5  2.5  0.75  1.5  1.5  0.5  0.5  0.5    8
#  525  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5    8
#  526  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5    8
#  527  0.75  0.5  2.5  2.50  1.5  1.5  0.5  0.5  0.5    8
#  528  1.50  0.5  0.5  0.75  1.5  2.5  0.5  2.5  2.5    1
#
#  [528 rows x 10 columns],
#  0      145.80
#  1      185.60
#  2      203.60
#  3      190.20
#  4      193.80
#          ...
#  524    192.07
#  525    196.80
#  526    206.73
#  527    172.46
#  528    149.80
#  Name: height, Length: 528, dtype: float64)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(xh,yh,random_state=42,test_size=0.33)

# %%
X_train.shape,Y_train.shape,X_test.shape,Y_test.shape
# Out:
# ((353, 10), (353,), (175, 10), (175,))

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error as mae 
from sklearn.metrics import mean_squared_error as mse 
from sklearn.metrics import mean_absolute_percentage_error as mape
model_rr=RandomForestRegressor(n_estimators=14,max_depth=4,random_state=42,criterion='squared_error')
from sklearn.ensemble import BaggingRegressor
bg_model=BaggingRegressor(base_estimator=model_rr,n_estimators=2,random_state=42)
bg_model.fit(X_train,Y_train)
Y_pred=bg_model.predict(X_test)
mae(Y_test, Y_pred)
# Out:
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# (15.466648912137632, 87.76464000553958)

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape 
model_rr.fit(X_train,Y_train)
YY_pred=model_rr.predict(X_test)
print("predicted accuracy is: ",(1-mape(Y_test,YY_pred))*100)
# Out:
# predicted accuracy is:  87.39245435014217

# %%
# bagging regressor
from sklearn.metrics import mean_absolute_percentage_error as mape 
print("predicted accuracy is: ",(1-mape(Y_test,Y_pred))*100)
# Out:
# predicted accuracy is:  87.76464000553958

# %%
np.corrcoef(Y_pred,Y_test)
# Out:
# array([[1.        , 0.74758368],
#        [0.74758368, 1.        ]])

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
train_score=[]
test_score=[]
values=[i for i in range(1,30)]
for i in range(1,30):
  model_1=bg_model=BaggingRegressor(base_estimator=model_rr,n_estimators=i,random_state=42)
  model_1.fit(X_train,Y_train)
  Y_pred1=model_1.predict(X_train)
  acc1=mae(Y_train,Y_pred1)
  Y_pred2=model_1.predict(X_test)
  acc2=mae(Y_pred2,Y_test)
  train_score.append(acc1)
  test_score.append(acc2)
plt.plot(values,train_score,label="train")
plt.plot(values,test_score,label="test")
plt.xlabel("estimators")
plt.ylabel("mae")
plt.legend()
plt.show()
# Out:
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(

# %%
lmc=model_r
lmr=bg_model
lmc,lmr
# Out:
# (RandomForestClassifier(max_depth=9, max_leaf_nodes=30, n_estimators=7,
#                         random_state=42),
#  BaggingRegressor(base_estimator=RandomForestRegressor(max_depth=4,
#                                                        n_estimators=14,
#                                                        random_state=42),
#                   n_estimators=29, random_state=42))

# %%
import random
import json
nuc=['A','T','C','G']
ss=[]

ss=['GCCTTTTTC']
import numpy as np
import pandas as pd
dicc={'A':1.5,'T':2.5,'C':0.5,'G':0.75}
encoded=[]
for i in ss:
  array = np.array(list(i))
  new_arr=np.array([dicc[i] for i in array])
  encoded.append((new_arr))

enc_dfff=pd.DataFrame(encoded)
zz=lmc.predict(enc_dfff)
id=list(zz) 
enc_dfff['sub']=id
enc_dfff.columns=enc_dfff.columns.astype(str)
enc_dfff['sub']=enc_dfff['sub'].astype('category').cat.codes + 1
res=lmr.predict(enc_dfff)
res_df=pd.DataFrame()
res_df['sequence']=ss
res_df['subpopulation']=id
res_df['height']=res
rl=res_df.values.tolist()
rl
# Out:
# c:\Users\Asus\anaconda3\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# [['GCCTTTTTC', 'Indica I', 163.93442302030738]]

# %%
zz
# Out:
# array(['Indica I'], dtype=object)
